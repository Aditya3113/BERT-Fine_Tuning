# %% [markdown]
# # 📘 Notebook 1 — Setup & Configuration
# ## Suicidal Ideation Detection using Transformer Models
# **Paper:** *Comparative Analysis of Transformer-based Models with Multi-Scale CNN Attention Fusion for Suicidal Ideation Detection in Social Media Text*
#
# ---
#
# ### Research Overview
# | Component | Details |
# |---|---|
# | Task | Binary classification: `suicide` vs `non-suicide` |
# | Baseline models | BERT, RoBERTa, DistilBERT |
# | Proposed model | BERT-CNN (novel contribution) |
# | Dataset | NLP Mental Health Reddit dataset |
# | Key metrics | Macro F1, ROC-AUC, Precision, Recall |
#
# > **Run this notebook first.** All config variables are imported by subsequent notebooks.

# %%
# !pip install torch transformers scikit-learn pandas numpy matplotlib seaborn tqdm accelerate
# Out:
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 21.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 13.6 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.2/625.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 13.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 13.5 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:━━━━━━━━━━━━━━━━━━ 0/9 [sympy]
#       Successfully uninstalled sympy-1.13.2━━━━━ 0/9 [sympy]
#   Attempting uninstall: regex━━━━━━━━━━━━━━━━━━━ 0/9 [sympy]
# ...

# %% [markdown]
# ## 1.1 Imports

# %%
import os
import torch
import warnings
warnings.filterwarnings('ignore')

print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU             : {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version : 2.11.0
# CUDA available  : False

# %% [markdown]
# ## 1.2 Global Configuration
# All hyperparameters are defined here. Modify this single cell to adjust any setting across the entire pipeline.

# %%
# ─── Paths ────────────────────────────────────────────────
DATA_PATH      = "suicide_detection.csv"   # ← update to your CSV path
OUTPUT_DIR     = "outputs"
LOG_DIR        = "logs"
CHECKPOINT_DIR = "checkpoints"

# ─── Dataset ──────────────────────────────────────────────
TEXT_COLUMN  = "text"
LABEL_COLUMN = "class"
LABEL_MAP    = {"suicide": 1, "non-suicide": 0}
TEST_SIZE    = 0.15
VAL_SIZE     = 0.15
RANDOM_SEED  = 42

# ─── Training ─────────────────────────────────────────────
MAX_LENGTH          = 512
BATCH_SIZE          = 16
EPOCHS              = 5
LEARNING_RATE       = 2e-5
WARMUP_RATIO        = 0.1
WEIGHT_DECAY        = 0.01
GRAD_CLIP           = 1.0
EARLY_STOP_PATIENCE = 3

# ─── Model checkpoints ────────────────────────────────────
MODELS = {
    "BERT":       "bert-base-uncased",
    "RoBERTa":    "roberta-base",
    "DistilBERT": "distilbert-base-uncased",
    "BERT-CNN":   "bert-base-uncased",   # proposed hybrid model
}

# ─── Proposed BERT-CNN Hyperparameters ────────────────────
CNN_FILTERS      = 256
CNN_KERNEL_SIZES = [2, 3, 4]   # bigram, trigram, 4-gram windows
DROPOUT_RATE     = 0.3
FOCAL_LOSS_GAMMA = 2.0
FOCAL_LOSS_ALPHA = 0.25

# ─── Device ───────────────────────────────────────────────
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {DEVICE}")

# ─── Plot palette ─────────────────────────────────────────
PALETTE = {
    "BERT":       "#1f77b4",
    "RoBERTa":    "#ff7f0e",
    "DistilBERT": "#2ca02c",
    "BERT-CNN":   "#d62728",   # red = proposed model
}

# Create output directories
for d in [OUTPUT_DIR, LOG_DIR, CHECKPOINT_DIR]:
    os.makedirs(d, exist_ok=True)

print("\nAll configuration loaded. Proceed to Notebook 2.")
# Out:
# Device: cpu
#
# All configuration loaded. Proceed to Notebook 2.
